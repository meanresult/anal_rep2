# %%
import pandas as pd
data_df = pd.read_csv('datalab (1).csv')
data_df.head()
# Out:
#            날짜      스트레스       성장        게임        운동
# 0  2024-07-14  16.44970  6.92307  73.90532  48.75739
# 1  2024-07-15  21.59763  8.34319  59.17159  50.35502
# 2  2024-07-16  22.48520  8.99408  60.41420  49.40828
# 3  2024-07-17  23.37278  8.40236  65.50295  48.81656
# 4  2024-07-18  23.96449  7.92899  59.52662  41.95266

# %%
corr_df = data_df[['스트레스', '성장','게임','운동']]
corr_df.corr()
# Out:
#           스트레스        성장        게임        운동
# 스트레스  1.000000  0.556168 -0.667819  0.448924
# 성장    0.556168  1.000000 -0.509953  0.465210
# 게임   -0.667819 -0.509953  1.000000 -0.449321
# 운동    0.448924  0.465210 -0.449321  1.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(corr_df['스트레스'], corr_df['취업'] )
plt.show()

# %%
import pandas as pd
data_df = pd.read_csv('datalab (2).csv')
data_df.head()
# Out:
#            날짜     스트레스       남편      자영업     남자친구        대출
# 0  2024-07-14  2.14385  1.26220  0.95775  2.65761  15.91399
# 1  2024-07-15  2.67664  1.73157  1.83940  1.42712  33.24876
# 2  2024-07-16  2.97475  1.52226  2.10579  1.50957  32.18952
# 3  2024-07-17  3.06355  1.70620  1.83305  1.67448  28.52974
# 4  2024-07-18  3.10161  1.75060  1.68083  1.48420  27.29925

# %%
corr_df = data_df[['스트레스', '남편','자영업','남자친구','대출']]
corr_df.corr()
# Out:
#           스트레스        남편       자영업      남자친구        대출
# 스트레스  1.000000  0.656652  0.548207 -0.124082  0.605809
# 남편    0.656652  1.000000  0.481068 -0.114515  0.500326
# 자영업   0.548207  0.481068  1.000000  0.012641  0.493731
# 남자친구 -0.124082 -0.114515  0.012641  1.000000 -0.106201
# 대출    0.605809  0.500326  0.493731 -0.106201  1.000000

# %%
import pandas as pd
data_df = pd.read_csv('datalab.csv')
data_df.head()
# Out:
#            날짜      스트레스        취업
# 0  2024-07-14  74.22178  47.85992
# 1  2024-07-15  93.19066  70.13618
# 2  2024-07-16  96.69260  66.14785
# 3  2024-07-17  93.77431  63.22957
# 4  2024-07-18  90.56420  56.71206

# %%
corr_df = data_df[['스트레스', '취업']]
corr_df.corr()
# Out:
#           스트레스        취업
# 스트레스  1.000000  0.593673
# 취업    0.593673  1.000000

# %%
import pandas as pd
data_df = pd.read_csv('datalab (3).csv')
data_df.head()
# Out:
#            날짜        취업      스트레스        결혼
# 0  2024-07-14  15.25974  23.37662  42.04545
# 1  2024-07-15  26.94805  33.92857  59.90259
# 2  2024-07-16  20.94155  31.16883  56.00649
# 3  2024-07-17  18.99350  34.90259  39.28571
# 4  2024-07-18  16.72077  34.41558  42.85714

# %%
corr_df = data_df[['스트레스', '취업','결혼']]
corr_df.corr()
# Out:
#           스트레스        취업        결혼
# 스트레스  1.000000  0.611400  0.281294
# 취업    0.611400  1.000000  0.304677
# 결혼    0.281294  0.304677  1.000000

# %%
import pandas as pd
data_df = pd.read_csv('datalab (4).csv')
data_df.head()
# Out:
#            날짜       스트레스        시험
# 0  2016-01-01   69.85788  14.57364
# 1  2016-02-01   62.36434  11.84754
# 2  2016-03-01   86.51162  20.19379
# 3  2016-04-01   83.92764  65.49095
# 4  2016-05-01  100.00000  32.81653

# %%
import pandas as pd
data_df = pd.read_csv('datalab (5).csv')
data_df.head()
# Out:
#            날짜      스트레스        취업
# 0  2021-03-01  34.69387  47.95918
# 1  2021-03-02  34.69387  77.55102
# 2  2021-03-03  32.65306  62.24489
# 3  2021-03-04  37.75510  61.22448
# 4  2021-03-05  28.57142  38.77551

# %%
import pandas as pd
data_df = pd.read_csv('datalab (6).csv')
data_df.head()
# Out:
#            날짜      스트레스         취업
# 0  2021-03-01  55.47744  100.00000
# 1  2021-04-01  51.90392   82.71821
# 2  2021-05-01  50.26362   79.84768
# 3  2021-06-01  56.00468   78.32454
# 4  2021-07-01  50.49794   83.12829

# %%
corr_df = data_df[['스트레스', '시험']]
corr_df.corr()
# Out:
#           스트레스        시험
# 스트레스  1.000000  0.703888
# 시험    0.703888  1.000000

# %%
corr_df = data_df[['스트레스', '취업']]
corr_df.corr()
# Out:
#           스트레스        취업
# 스트레스  1.000000  0.665755
# 취업    0.665755  1.000000
